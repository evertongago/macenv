# %%
import pandas
from matplotlib import pyplot

pyplot.rcParams['figure.figsize'] = (15, 8)

# %%
df = pandas.read_csv('data/tests.csv')
df.rename(columns={
    'datetime': 'Date',
    'high': 'High',
    'low': 'Low',
    'open': 'Open',
    'close': 'Close',
    'volume': 'Volume'
}, inplace=True)

df = df[26:266]

# %%
df.head()
# Out:
#                    Date    High     Low    Open   Close  Volume
# 26  2021.08.02 09:01:00  123380  123325  123350  123375  1624.0
# 27  2021.08.02 09:01:01  123465  123375  123375  123455  1703.0
# 28  2021.08.02 09:01:02  123485  123395  123450  123415  3181.0
# 29  2021.08.02 09:01:03  123435  123395  123420  123395  1037.0
# 30  2021.08.02 09:01:04  123425  123380  123395  123420  1162.0

# %%
df.tail()
# Out:
#                     Date    High     Low    Open   Close  Volume
# 261  2021.08.02 09:04:55  123320  123305  123310  123315   144.0
# 262  2021.08.02 09:04:56  123310  123290  123310  123310   517.0
# 263  2021.08.02 09:04:57  123315  123300  123305  123300   314.0
# 264  2021.08.02 09:04:58  123320  123300  123300  123315   444.0
# 265  2021.08.02 09:04:59  123320  123300  123315  123305   245.0

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:>

# %%
df.to_csv('/Users/everton.gago/Documents/repositories/trading/tests/files/data/data.csv', header=True, index=False)
